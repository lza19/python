# %%
l1 = [1,5,5,694,48,45]
l2 = [5,48,45,1,694,5]
l3 = ['a','b','c','d']
s1 = "hello"

# %%
for i in l1:
    print(i)

for i in s1:
    print(i)
# Out:
# 1
# 5
# 5
# 694
# 48
# 45
# h
# e
# l
# l
# o
