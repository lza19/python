# %%
lista = [1, 2, 3, 4, 5]
lista1 = ['apple', 'banana', 'cherry', 'date']
a = list((10, 20, 30))

# %%
lista1.sort()
print(lista1)
# Out:
# ['apple', 'banana', 'cherry', 'date']

# %%
print(type(lista), type(a))
# Out:
# <class 'list'> <class 'list'>

# %%
list3 = lista + lista1
print(list3)
# Out:
# [1, 2, 3, 4, 5, 'apple', 'banana', 'cherry', 'date']
