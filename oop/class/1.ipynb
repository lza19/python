# %%
for i in range(1):
    x + y = z
    print(z)

# %%
class animal:
    # method
    def hello(self):
        print("Animal class says hello")

    def bye(x, y):
        z = x+y
        print(z)

# %%
class animal1:
    # method
    def hello(self):
        print("Animal class says hello")

    def bye(self,x, y):
        z = x+y
        print(z)

    def user(selt):
        selt.name = "John"
        print("name :",selt.name)

# %%
an1 = animal1()
an1.user()
# Out:
# name : John

# %%
print(type(animal))
print(animal.__name__)
print(animal)
# Out:
# <class 'type'>
# animal
# <class '__main__.animal'>

# %%
x = animal1()
print(x.hello())
x.hello()
# Out:
# Animal class says hello
# None
# Animal class says hello

# %%
x.bye(10, 20)
# Out:
# 30
