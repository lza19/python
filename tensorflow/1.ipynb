# %%
import os
import tensorflow as tf

# %%
print(tf.__version__)
# Out:
# 2.10.0

# %%
pathtest1 = r"D:\final_facenet\testdataset\1074\73614.jpg"
def imagesposes(image):
    image = tf.io.read_file(image)
    return image

print(type(imagesposes(pathtest1)))
# Out:
# ---------------------------------------------------------------------------
# InvalidArgumentError                      Traceback (most recent call last)
# Cell In[8], line 9
#       6     image = tf.image.resize(image, [256, 256])
#       7     return image
# ----> 9 print(type(imagesposes(pathtest1)))
#
# Cell In[8], line 3, in imagesposes(image)
#       2 def imagesposes(image):
# ----> 3     image = tf.io.read_file(image)
#       4     image = tf.image.decode_jpeg(image, channels=3)
#       5     image = tf.cast(image, tf.float32)
#
# File d:\Pythonv\myenv\lib\site-packages\tensorflow\python\ops\io_ops.py:133, in read_file(filename, name)
#      96 @tf_export("io.read_file", v1=["io.read_file", "read_file"])
#      97 def read_file(filename, name=None):
#      98   """Reads the contents of file.
#      99
#     100   This operation returns a tensor with the entire contents of the input
#    (...)
#     131     A tensor of dtype "string", with the file contents.
#     132   """
# ...

# %%
def imagesposes(image):
    image = tf.io.read_file(image)
    return image

print(type(imagesposes(pathtest1)))

# %%
print(type(imagesposes(pathtest1)))
# Out:
# ---------------------------------------------------------------------------
# InvalidArgumentError                      Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 print(type(imagesposes(pathtest1)))
#
# Cell In[18], line 2, in imagesposes(image)
#       1 def imagesposes(image):
# ----> 2     image = tf.io.read_file(image)
#       3     return image
#
# File d:\Pythonv\myenv\lib\site-packages\tensorflow\python\ops\io_ops.py:133, in read_file(filename, name)
#      96 @tf_export("io.read_file", v1=["io.read_file", "read_file"])
#      97 def read_file(filename, name=None):
#      98   """Reads the contents of file.
#      99
#     100   This operation returns a tensor with the entire contents of the input
#    (...)
#     131     A tensor of dtype "string", with the file contents.
#     132   """
# --> 133   return gen_io_ops.read_file(filename, name)
#
# ...

# %%
l1 = [1,5,5,694,48,45]
l2 = [5,48,45,1,694,5]
l3 = ['a','b','c','d']
s1 = "hello"
l2.sort()
l2.append(100)
li = list(s1)

# %%
pathtest = "D:/Pythonv"

# %%
for i in os.listdir(pathtest):
    la = os.path.join(pathtest,i)
    print(la)
# Out:
# D:/Pythonv\.git
# D:/Pythonv\.gitignore
# D:/Pythonv\dictionary
# D:/Pythonv\list
# D:/Pythonv\loop
# D:/Pythonv\math
# D:/Pythonv\matplotlib
# D:/Pythonv\myenv
# D:/Pythonv\numpy
# D:/Pythonv\oop
# D:/Pythonv\os
# D:/Pythonv\re.txt
# D:/Pythonv\tutle

# %%
for i in l1:
    
    print(i)

for i in s1:
    print(i)
# Out:
# 1
# 5
# 5
# 694
# 48
# 45
# h
# e
# l
# l
# o

# %%
testdata = r"D:\final_facenet\testdataset"

# %%
for i in os.listdir(testdata):
    i = os.path.join(testdata,i)
    for j in os.listdir(i):
        j = os.path.join(i,j)
        
        print(j)
# Out:
# D:\final_facenet\testdataset\1064\72965.jpg
# D:\final_facenet\testdataset\1064\72966.jpg
# D:\final_facenet\testdataset\1064\72967.jpg
# D:\final_facenet\testdataset\1064\72968.jpg
# D:\final_facenet\testdataset\1064\72969.jpg
# D:\final_facenet\testdataset\1064\72970.jpg
# D:\final_facenet\testdataset\1064\72971.jpg
# D:\final_facenet\testdataset\1064\72972.jpg
# D:\final_facenet\testdataset\1064\72973.jpg
# D:\final_facenet\testdataset\1064\72974.jpg
# D:\final_facenet\testdataset\1064\72975.jpg
# D:\final_facenet\testdataset\1064\72976.jpg
# D:\final_facenet\testdataset\1064\72977.jpg
# D:\final_facenet\testdataset\1064\72978.jpg
# D:\final_facenet\testdataset\1064\72979.jpg
# D:\final_facenet\testdataset\1064\72980.jpg
# D:\final_facenet\testdataset\1064\72981.jpg
# D:\final_facenet\testdataset\1064\72982.jpg
# D:\final_facenet\testdataset\1064\72983.jpg
# D:\final_facenet\testdataset\1064\72984.jpg
# D:\final_facenet\testdataset\1064\72985.jpg
# ...
